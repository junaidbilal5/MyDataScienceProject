# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

pd.options.display.max_seq_items = None

# %%
coders = pd.read_csv("2017-fCC-New-Coders-Survey-Data.csv", low_memory = False)
coders.head()
# Out:
#     Age  AttendedBootcamp  BootcampFinish  BootcampLoanYesNo BootcampName  \
# 0  27.0               0.0             NaN                NaN          NaN
# 1  34.0               0.0             NaN                NaN          NaN
# 2  21.0               0.0             NaN                NaN          NaN
# 3  26.0               0.0             NaN                NaN          NaN
# 4  20.0               0.0             NaN                NaN          NaN
#
#    BootcampRecommend  ChildrenNumber                 CityPopulation  \
# 0                NaN             NaN            more than 1 million
# 1                NaN             NaN              less than 100,000
# 2                NaN             NaN            more than 1 million
# 3                NaN             NaN  between 100,000 and 1 million
# 4                NaN             NaN  between 100,000 and 1 million
#
#    CodeEventConferences  CodeEventDjangoGirls  ...  YouTubeFCC  \
# 0                   NaN                   NaN  ...         NaN
# 1                   NaN                   NaN  ...         1.0
# 2                   NaN                   NaN  ...         NaN
# 3                   NaN                   NaN  ...         1.0
# 4                   NaN                   NaN  ...         NaN
#
#    YouTubeFunFunFunction  YouTubeGoogleDev  YouTubeLearnCode  \
# 0                    NaN               NaN               NaN
# 1                    NaN               NaN               NaN
# 2                    NaN               NaN               1.0
# 3                    1.0               NaN               NaN
# 4                    NaN               NaN               NaN
#
#    YouTubeLevelUpTuts  YouTubeMIT  YouTubeMozillaHacks YouTubeOther  \
# 0                 NaN         NaN                  NaN          NaN
# 1                 NaN         NaN                  NaN          NaN
# 2                 1.0         NaN                  NaN          NaN
# 3                 1.0         NaN                  NaN          NaN
# 4                 NaN         NaN                  NaN          NaN
#
#    YouTubeSimplilearn  YouTubeTheNewBoston
# 0                 NaN                  NaN
# 1                 NaN                  NaN
# 2                 NaN                  NaN
# 3                 NaN                  NaN
# 4                 NaN                  NaN
#
# [5 rows x 136 columns]

# %%
coders.columns
# Out:
# Index(['Age', 'AttendedBootcamp', 'BootcampFinish', 'BootcampLoanYesNo',
#        'BootcampName', 'BootcampRecommend', 'ChildrenNumber', 'CityPopulation',
#        'CodeEventConferences', 'CodeEventDjangoGirls', 'CodeEventFCC',
#        'CodeEventGameJam', 'CodeEventGirlDev', 'CodeEventHackathons',
#        'CodeEventMeetup', 'CodeEventNodeSchool', 'CodeEventNone',
#        'CodeEventOther', 'CodeEventRailsBridge', 'CodeEventRailsGirls',
#        'CodeEventStartUpWknd', 'CodeEventWkdBootcamps', 'CodeEventWomenCode',
#        'CodeEventWorkshops', 'CommuteTime', 'CountryCitizen', 'CountryLive',
#        'EmploymentField', 'EmploymentFieldOther', 'EmploymentStatus',
#        'EmploymentStatusOther', 'ExpectedEarning', 'FinanciallySupporting',
#        'FirstDevJob', 'Gender', 'GenderOther', 'HasChildren', 'HasDebt',
#        'HasFinancialDependents', 'HasHighSpdInternet', 'HasHomeMortgage',
#        'HasServedInMilitary', 'HasStudentDebt', 'HomeMortgageOwe',
#        'HoursLearning', 'ID.x', 'ID.y', 'Income', 'IsEthnicMinority',
#        'IsReceiveDisabilitiesBenefits', 'IsSoftwareDev', 'IsUnderEmployed',
#        'JobApplyWhen', 'JobInterestBackEnd', 'JobInterestDataEngr',
#        'JobInterestDataSci', 'JobInterestDevOps', 'JobInterestFrontEnd',
#        'JobInterestFullStack', 'JobInterestGameDev', 'JobInterestInfoSec',
#        'JobInterestMobile', 'JobInterestOther', 'JobInterestProjMngr',
#        'JobInterestQAEngr', 'JobInterestUX', 'JobPref', 'JobRelocateYesNo',
#        'JobRoleInterest', 'JobWherePref', 'LanguageAtHome', 'MaritalStatus',
#        'MoneyForLearning', 'MonthsProgramming', 'NetworkID', 'Part1EndTime',
#        'Part1StartTime', 'Part2EndTime', 'Part2StartTime', 'PodcastChangeLog',
#        'PodcastCodeNewbie', 'PodcastCodePen', 'PodcastDevTea', 'PodcastDotNET',
#        'PodcastGiantRobots', 'PodcastJSAir', 'PodcastJSJabber', 'PodcastNone',
#        'PodcastOther', 'PodcastProgThrowdown', 'PodcastRubyRogues',
#        'PodcastSEDaily', 'PodcastSERadio', 'PodcastShopTalk',
#        'PodcastTalkPython', 'PodcastTheWebAhead', 'ResourceCodecademy',
#        'ResourceCodeWars', 'ResourceCoursera', 'ResourceCSS', 'ResourceEdX',
#        'ResourceEgghead', 'ResourceFCC', 'ResourceHackerRank', 'ResourceKA',
#        'ResourceLynda', 'ResourceMDN', 'ResourceOdinProj', 'ResourceOther',
#        'ResourcePluralSight', 'ResourceSkillcrush', 'ResourceSO',
#        'ResourceTreehouse', 'ResourceUdacity', 'ResourceUdemy', 'ResourceW3S',
#        'SchoolDegree', 'SchoolMajor', 'StudentDebtOwe', 'YouTubeCodeCourse',
#        'YouTubeCodingTrain', 'YouTubeCodingTut360', 'YouTubeComputerphile',
#        'YouTubeDerekBanas', 'YouTubeDevTips', 'YouTubeEngineeredTruth',
#        'YouTubeFCC', 'YouTubeFunFunFunction', 'YouTubeGoogleDev',
#        'YouTubeLearnCode', 'YouTubeLevelUpTuts', 'YouTubeMIT',
#        'YouTubeMozillaHacks', 'YouTubeOther', 'YouTubeSimplilearn',
#        'YouTubeTheNewBoston'],
#       dtype='object')

# %%
coders['JobRoleInterest'].value_counts()
# Out:
# Full-Stack Web Developer                                                                                                                                                 823
#   Front-End Web Developer                                                                                                                                                450
#   Data Scientist                                                                                                                                                         152
# Back-End Web Developer                                                                                                                                                   142
#   Mobile Developer                                                                                                                                                       117
#                                                                                                                                                                         ...
# Full-Stack Web Developer,   Front-End Web Developer,   Mobile Developer,   Data Scientist,   Product Manager,   User Experience Designer                                   1
# Back-End Web Developer,   DevOps / SysAdmin,   Data Scientist, Data Engineer, Full-Stack Web Developer                                                                     1
#   Data Scientist,   Product Manager, Data Engineer,   Front-End Web Developer,   Mobile Developer, Game Developer, Back-End Web Developer,   User Experience Designer      1
# Full-Stack Web Developer, Data Engineer,   Front-End Web Developer, Back-End Web Developer,   Data Scientist                                                               1
# Game Developer, Information Security, Back-End Web Developer,   DevOps / SysAdmin                                                                                          1
# Name: JobRoleInterest, Length: 3213, dtype: int64

# %%
coders['JobRoleInterest'].value_counts(normalize = True)*100
# Out:
# Full-Stack Web Developer                                                                                                                                                 11.770595
#   Front-End Web Developer                                                                                                                                                 6.435927
#   Data Scientist                                                                                                                                                          2.173913
# Back-End Web Developer                                                                                                                                                    2.030892
#   Mobile Developer                                                                                                                                                        1.673341
#                                                                                                                                                                            ...
# Full-Stack Web Developer,   Front-End Web Developer,   Mobile Developer,   Data Scientist,   Product Manager,   User Experience Designer                                  0.014302
# Back-End Web Developer,   DevOps / SysAdmin,   Data Scientist, Data Engineer, Full-Stack Web Developer                                                                    0.014302
#   Data Scientist,   Product Manager, Data Engineer,   Front-End Web Developer,   Mobile Developer, Game Developer, Back-End Web Developer,   User Experience Designer     0.014302
# Full-Stack Web Developer, Data Engineer,   Front-End Web Developer, Back-End Web Developer,   Data Scientist                                                              0.014302
# Game Developer, Information Security, Back-End Web Developer,   DevOps / SysAdmin                                                                                         0.014302
# Name: JobRoleInterest, Length: 3213, dtype: float64

# %%
def count_lst(lst):
    return len(lst)

# %%
coders['JobRoleInterest'].dropna().str.split(",").map(count_lst).value_counts()
# Out:
# 1     2213
# 3     1111
# 4     1064
# 5      842
# 2      761
# 6      470
# 7      270
# 8      123
# 9       69
# 10      33
# 12      21
# 11      13
# 13       2
# Name: JobRoleInterest, dtype: int64

# %%
coders['JobRoleInterest'].dropna().str.split(",").str.len().value_counts()
# Out:
# 1     2213
# 3     1111
# 4     1064
# 5      842
# 2      761
# 6      470
# 7      270
# 8      123
# 9       69
# 10      33
# 12      21
# 11      13
# 13       2
# Name: JobRoleInterest, dtype: int64

# %%
area_of_int = "Web Developer", "Mobile Developer"

# %%
type(area_of_int)
# Out:
# tuple

# %%
coders['JobRoleInterest'].isin(['  Data Scientist']).sum()
# Out:
# 152

# %%
coders['JobRoleInterest'].iloc[11]
# Out:
# '  DevOps / SysAdmin,   Data Scientist, Information Security, Data Engineer'

# %%
coders['JobRoleInterest'].isin(["Web Developer", "Mobile Developer"]).sum()
# Out:
# 0

# %%
coders['JobRoleInterest'].str.contains("Web Developer|Mobile Developer").sum()
# Out:
# 6030

# %%
not_null = coders['JobRoleInterest'].dropna()

# %%
not_null.shape
# Out:
# (6992,)

# %%
not_null.str.contains("Web Developer|Mobile Developer").sum()
# Out:
# 6030

# %%
rep = not_null.str.contains("Web Developer|Mobile Developer").value_counts(normalize = True)*100

# %%
type(rep)
# Out:
# pandas.core.series.Series

# %%
rep.plot.bar()
plt.show()

# %%
rep.plot.pie(autopct = "%.1f%%")
plt.legend()
plt.show()

# %%
fcc = coders[coders['JobRoleInterest'].notnull()].copy()

# %%
fcc.shape
# Out:
# (6992, 136)

# %%
import re

# %%
fcc.columns[fcc.columns.str.contains("coun", flags = re.I )] # here I is ignore case
# Out:
# Index(['CountryCitizen', 'CountryLive'], dtype='object')

# %%
fcc.columns
# Out:
# Index(['Age', 'AttendedBootcamp', 'BootcampFinish', 'BootcampLoanYesNo',
#        'BootcampName', 'BootcampRecommend', 'ChildrenNumber', 'CityPopulation',
#        'CodeEventConferences', 'CodeEventDjangoGirls', 'CodeEventFCC',
#        'CodeEventGameJam', 'CodeEventGirlDev', 'CodeEventHackathons',
#        'CodeEventMeetup', 'CodeEventNodeSchool', 'CodeEventNone',
#        'CodeEventOther', 'CodeEventRailsBridge', 'CodeEventRailsGirls',
#        'CodeEventStartUpWknd', 'CodeEventWkdBootcamps', 'CodeEventWomenCode',
#        'CodeEventWorkshops', 'CommuteTime', 'CountryCitizen', 'CountryLive',
#        'EmploymentField', 'EmploymentFieldOther', 'EmploymentStatus',
#        'EmploymentStatusOther', 'ExpectedEarning', 'FinanciallySupporting',
#        'FirstDevJob', 'Gender', 'GenderOther', 'HasChildren', 'HasDebt',
#        'HasFinancialDependents', 'HasHighSpdInternet', 'HasHomeMortgage',
#        'HasServedInMilitary', 'HasStudentDebt', 'HomeMortgageOwe',
#        'HoursLearning', 'ID.x', 'ID.y', 'Income', 'IsEthnicMinority',
#        'IsReceiveDisabilitiesBenefits', 'IsSoftwareDev', 'IsUnderEmployed',
#        'JobApplyWhen', 'JobInterestBackEnd', 'JobInterestDataEngr',
#        'JobInterestDataSci', 'JobInterestDevOps', 'JobInterestFrontEnd',
#        'JobInterestFullStack', 'JobInterestGameDev', 'JobInterestInfoSec',
#        'JobInterestMobile', 'JobInterestOther', 'JobInterestProjMngr',
#        'JobInterestQAEngr', 'JobInterestUX', 'JobPref', 'JobRelocateYesNo',
#        'JobRoleInterest', 'JobWherePref', 'LanguageAtHome', 'MaritalStatus',
#        'MoneyForLearning', 'MonthsProgramming', 'NetworkID', 'Part1EndTime',
#        'Part1StartTime', 'Part2EndTime', 'Part2StartTime', 'PodcastChangeLog',
#        'PodcastCodeNewbie', 'PodcastCodePen', 'PodcastDevTea', 'PodcastDotNET',
#        'PodcastGiantRobots', 'PodcastJSAir', 'PodcastJSJabber', 'PodcastNone',
#        'PodcastOther', 'PodcastProgThrowdown', 'PodcastRubyRogues',
#        'PodcastSEDaily', 'PodcastSERadio', 'PodcastShopTalk',
#        'PodcastTalkPython', 'PodcastTheWebAhead', 'ResourceCodecademy',
#        'ResourceCodeWars', 'ResourceCoursera', 'ResourceCSS', 'ResourceEdX',
#        'ResourceEgghead', 'ResourceFCC', 'ResourceHackerRank', 'ResourceKA',
#        'ResourceLynda', 'ResourceMDN', 'ResourceOdinProj', 'ResourceOther',
#        'ResourcePluralSight', 'ResourceSkillcrush', 'ResourceSO',
#        'ResourceTreehouse', 'ResourceUdacity', 'ResourceUdemy', 'ResourceW3S',
#        'SchoolDegree', 'SchoolMajor', 'StudentDebtOwe', 'YouTubeCodeCourse',
#        'YouTubeCodingTrain', 'YouTubeCodingTut360', 'YouTubeComputerphile',
#        'YouTubeDerekBanas', 'YouTubeDevTips', 'YouTubeEngineeredTruth',
#        'YouTubeFCC', 'YouTubeFunFunFunction', 'YouTubeGoogleDev',
#        'YouTubeLearnCode', 'YouTubeLevelUpTuts', 'YouTubeMIT',
#        'YouTubeMozillaHacks', 'YouTubeOther', 'YouTubeSimplilearn',
#        'YouTubeTheNewBoston'],
#       dtype='object')

# %%
fcc['MonthsProgramming'].value_counts().sort_index()
# Out:
# 0.0      235
# 1.0      767
# 2.0      669
# 3.0      637
# 4.0      367
#         ...
# 360.0      5
# 370.0      1
# 408.0      1
# 480.0      2
# 744.0      4
# Name: MonthsProgramming, Length: 91, dtype: int64

# %%
 fcc['MonthsProgramming'].replace(0,1).value_counts()
# Out:
# 1.0      1002
# 2.0       669
# 6.0       654
# 3.0       637
# 12.0      616
#          ...
# 49.0        1
# 171.0       1
# 198.0       1
# 105.0       1
# 51.0        1
# Name: MonthsProgramming, Length: 90, dtype: int64

# %%
fcc['MonthsProgramming'].replace(0,1, inplace = True)

# %%
fcc['MonthsProgramming'].isnull().sum()
# Out:
# 359

# %%
bol = fcc['MonthsProgramming'].isnull()

# %%
fcc.loc[bol,['MonthsProgramming','MoneyForLearning']]
# Out:
#        MonthsProgramming  MoneyForLearning
# 13                   NaN               NaN
# 29                   NaN             300.0
# 34                   NaN               NaN
# 37                   NaN               NaN
# 100                  NaN               NaN
# ...                  ...               ...
# 17727                NaN              50.0
# 17862                NaN               NaN
# 18052                NaN             500.0
# 18129                NaN               0.0
# 18163                NaN               0.0
#
# [359 rows x 2 columns]

# %%
fcc.loc[bol,'MoneyForLearning'].notnull().sum()
# Out:
# 159

# %%
fcc1 = fcc[fcc['MonthsProgramming'].notnull()].copy()

# %%
fcc1.shape
# Out:
# (6633, 136)

# %%
fcc1["CountryLive"].isnull().sum()
# Out:
# 114

# %%
fcc1["CountryLive"].notnull().sum()
# Out:
# 6519

# %%
fcc1 = fcc1[fcc1["CountryLive"].notnull()].copy()

# %%
fcc1.shape
# Out:
# (6519, 136)

# %%
fcc1["monthly_spend"] = fcc1['MoneyForLearning']/fcc1['MonthsProgramming']

# %%
fcc1.groupby("CountryLive")["monthly_spend"].mean().sort_values(ascending = False)
# Out:
# CountryLive
# Yemen          10000.000000
# Puerto Rico     4291.394558
# Austria          936.208333
# Spain            784.553084
# Jamaica          747.037037
#                    ...
# Aruba                   NaN
# Bolivia                 NaN
# Liberia                 NaN
# Panama                  NaN
# Qatar                   NaN
# Name: monthly_spend, Length: 136, dtype: float64

# %%
fcc1['MoneyForLearning'].max()
# Out:
# 200000.0

# %%
fcc1['MoneyForLearning'].min()
# Out:
# 0.0

# %%
fcc1.columns
# Out:
# Index(['Age', 'AttendedBootcamp', 'BootcampFinish', 'BootcampLoanYesNo',
#        'BootcampName', 'BootcampRecommend', 'ChildrenNumber', 'CityPopulation',
#        'CodeEventConferences', 'CodeEventDjangoGirls', 'CodeEventFCC',
#        'CodeEventGameJam', 'CodeEventGirlDev', 'CodeEventHackathons',
#        'CodeEventMeetup', 'CodeEventNodeSchool', 'CodeEventNone',
#        'CodeEventOther', 'CodeEventRailsBridge', 'CodeEventRailsGirls',
#        'CodeEventStartUpWknd', 'CodeEventWkdBootcamps', 'CodeEventWomenCode',
#        'CodeEventWorkshops', 'CommuteTime', 'CountryCitizen', 'CountryLive',
#        'EmploymentField', 'EmploymentFieldOther', 'EmploymentStatus',
#        'EmploymentStatusOther', 'ExpectedEarning', 'FinanciallySupporting',
#        'FirstDevJob', 'Gender', 'GenderOther', 'HasChildren', 'HasDebt',
#        'HasFinancialDependents', 'HasHighSpdInternet', 'HasHomeMortgage',
#        'HasServedInMilitary', 'HasStudentDebt', 'HomeMortgageOwe',
#        'HoursLearning', 'ID.x', 'ID.y', 'Income', 'IsEthnicMinority',
#        'IsReceiveDisabilitiesBenefits', 'IsSoftwareDev', 'IsUnderEmployed',
#        'JobApplyWhen', 'JobInterestBackEnd', 'JobInterestDataEngr',
#        'JobInterestDataSci', 'JobInterestDevOps', 'JobInterestFrontEnd',
#        'JobInterestFullStack', 'JobInterestGameDev', 'JobInterestInfoSec',
#        'JobInterestMobile', 'JobInterestOther', 'JobInterestProjMngr',
#        'JobInterestQAEngr', 'JobInterestUX', 'JobPref', 'JobRelocateYesNo',
#        'JobRoleInterest', 'JobWherePref', 'LanguageAtHome', 'MaritalStatus',
#        'MoneyForLearning', 'MonthsProgramming', 'NetworkID', 'Part1EndTime',
#        'Part1StartTime', 'Part2EndTime', 'Part2StartTime', 'PodcastChangeLog',
#        'PodcastCodeNewbie', 'PodcastCodePen', 'PodcastDevTea', 'PodcastDotNET',
#        'PodcastGiantRobots', 'PodcastJSAir', 'PodcastJSJabber', 'PodcastNone',
#        'PodcastOther', 'PodcastProgThrowdown', 'PodcastRubyRogues',
#        'PodcastSEDaily', 'PodcastSERadio', 'PodcastShopTalk',
#        'PodcastTalkPython', 'PodcastTheWebAhead', 'ResourceCodecademy',
#        'ResourceCodeWars', 'ResourceCoursera', 'ResourceCSS', 'ResourceEdX',
#        'ResourceEgghead', 'ResourceFCC', 'ResourceHackerRank', 'ResourceKA',
#        'ResourceLynda', 'ResourceMDN', 'ResourceOdinProj', 'ResourceOther',
#        'ResourcePluralSight', 'ResourceSkillcrush', 'ResourceSO',
#        'ResourceTreehouse', 'ResourceUdacity', 'ResourceUdemy', 'ResourceW3S',
#        'SchoolDegree', 'SchoolMajor', 'StudentDebtOwe', 'YouTubeCodeCourse',
#        'YouTubeCodingTrain', 'YouTubeCodingTut360', 'YouTubeComputerphile',
#        'YouTubeDerekBanas', 'YouTubeDevTips', 'YouTubeEngineeredTruth',
#        'YouTubeFCC', 'YouTubeFunFunFunction', 'YouTubeGoogleDev',
#        'YouTubeLearnCode', 'YouTubeLevelUpTuts', 'YouTubeMIT',
#        'YouTubeMozillaHacks', 'YouTubeOther', 'YouTubeSimplilearn',
#        'YouTubeTheNewBoston', 'monthly_spend'],
#       dtype='object')

# %%
fcc1["CountryLive"].value_counts()
# Out:
# United States of America    2998
# India                        503
# United Kingdom               296
# Canada                       252
# Poland                       125
#                             ...
# Papua New Guinea               1
# Rwanda                         1
# Samoa                          1
# Myanmar                        1
# Turkmenistan                   1
# Name: CountryLive, Length: 136, dtype: int64

# %%
fcc1["CountryLive"].value_counts().index
# Out:
# Index(['United States of America', 'India', 'United Kingdom', 'Canada',
#        'Poland', 'Brazil', 'Germany', 'Australia', 'Russia', 'Ukraine',
#        'Nigeria', 'Spain', 'France', 'Romania',
#        'Netherlands (Holland, Europe)', 'Italy', 'Serbia', 'Philippines',
#        'Ireland', 'Greece', 'South Africa', 'Mexico', 'Turkey', 'Hungary',
#        'Singapore', 'Croatia', 'Argentina', 'Norway', 'New Zealand',
#        'Pakistan', 'Sweden', 'Denmark', 'China', 'Indonesia', 'Egypt',
#        'Finland', 'Vietnam', 'Czech Republic', 'Malaysia', 'Kenya', 'Portugal',
#        'Israel', 'Lithuania', 'Japan', 'Bangladesh', 'Great Britain',
#        'Bosnia & Herzegovina', 'Belarus', 'United Arab Emirates', 'Belgium',
#        'Korea South', 'Nepal', 'Austria', 'Colombia', 'Venezuela',
#        'Switzerland', 'Republic of Serbia', 'Bulgaria', 'Taiwan', 'Latvia',
#        'Ghana', 'Thailand', 'Kazakhstan', 'Hong Kong', 'Macedonia', 'Jamaica',
#        'Slovenia', 'Sri Lanka', 'Saudi Arabia', 'Slovakia', 'Morocco',
#        'Estonia', 'Peru', 'Costa Rica', 'Dominican Republic', 'Puerto Rico',
#        'Albania', 'Luxembourg', 'Virgin Islands (USA)', 'Iran', 'Algeria',
#        'Chile', 'Uruguay', 'Tunisia', 'Azerbaijan', 'Georgia', 'Zimbabwe',
#        'Afghanistan', 'Uganda', 'Senegal', 'Netherland Antilles', 'Niger',
#        'Iceland', 'Cambodia', 'Uzbekistan', 'Paraguay', 'Lebanon', 'Mauritius',
#        'Moldova', 'Haiti', 'Ecuador', 'Bahrain', 'Cyprus', 'Iraq', 'Guam',
#        'Honduras', 'Bolivia', 'Somalia', 'Cuba', 'Guadeloupe', 'Mozambique',
#        'Channel Islands', 'Cameroon', 'Cayman Islands', 'Jordan', 'Gibraltar',
#        'Nicaragua', 'Gambia', 'Panama', 'Angola', 'Kyrgyzstan', 'Vanuatu',
#        'Anguilla', 'Nambia', 'Trinidad & Tobago', 'Yemen', 'Guatemala',
#        'Botswana', 'Liberia', 'Aruba', 'Qatar', 'Papua New Guinea', 'Rwanda',
#        'Samoa', 'Myanmar', 'Turkmenistan'],
#       dtype='object')

# %%
fcc_updated = fcc1[fcc1["CountryLive"].isin(['United States of America', 'India', 'United Kingdom', 'Canada'])]

# %%
fcc_updated.groupby("CountryLive")["monthly_spend"].mean().sort_values(ascending = False)
# Out:
# CountryLive
# United States of America    227.997996
# India                       135.100982
# Canada                      113.510961
# United Kingdom               45.534443
# Name: monthly_spend, dtype: float64

# %%
sns.boxplot(x ="CountryLive", y = "monthly_spend", data = fcc_updated)

# %%
bol1 = fcc_updated["monthly_spend"] < 20000

# %%
fcc_updated = fcc_updated[bol1]

# %%
fcc_updated.groupby("CountryLive")["monthly_spend"].mean().sort_values(ascending = False)
# Out:
# CountryLive
# United States of America    183.800110
# India                       135.100982
# Canada                      113.510961
# United Kingdom               45.534443
# Name: monthly_spend, dtype: float64

# %%
sns.boxplot(x ="CountryLive", y = "monthly_spend", data = fcc_updated)

# %%
bol2 = (fcc_updated["CountryLive"] =="India") & (fcc_updated["monthly_spend"] >= 2500)
fcc_updated[bol2]
# Out:
#         Age  AttendedBootcamp  BootcampFinish  BootcampLoanYesNo BootcampName  \
# 1728   24.0               0.0             NaN                NaN          NaN
# 1755   20.0               0.0             NaN                NaN          NaN
# 7989   28.0               0.0             NaN                NaN          NaN
# 8126   22.0               0.0             NaN                NaN          NaN
# 13398  19.0               0.0             NaN                NaN          NaN
# 15587  27.0               0.0             NaN                NaN          NaN
#
#        BootcampRecommend  ChildrenNumber                 CityPopulation  \
# 1728                 NaN             NaN  between 100,000 and 1 million
# 1755                 NaN             NaN            more than 1 million
# 7989                 NaN             NaN  between 100,000 and 1 million
# 8126                 NaN             NaN            more than 1 million
# 13398                NaN             NaN            more than 1 million
# 15587                NaN             NaN            more than 1 million
#
#        CodeEventConferences  CodeEventDjangoGirls  ...  YouTubeFunFunFunction  \
# 1728                    NaN                   NaN  ...                    NaN
# 1755                    NaN                   NaN  ...                    NaN
# 7989                    1.0                   NaN  ...                    NaN
# 8126                    NaN                   NaN  ...                    NaN
# 13398                   NaN                   NaN  ...                    NaN
# 15587                   NaN                   NaN  ...                    NaN
#
#        YouTubeGoogleDev  YouTubeLearnCode  YouTubeLevelUpTuts  YouTubeMIT  \
# 1728                NaN               NaN                 NaN         NaN
# 1755                NaN               1.0                 NaN         1.0
# 7989                NaN               NaN                 NaN         NaN
# 8126                1.0               NaN                 NaN         1.0
# 13398               NaN               NaN                 NaN         NaN
# 15587               1.0               1.0                 NaN         1.0
#
#        YouTubeMozillaHacks  YouTubeOther YouTubeSimplilearn  \
# 1728                   NaN           NaN                NaN
# 1755                   NaN           NaN                NaN
# 7989                   NaN           NaN                NaN
# 8126                   NaN           NaN                NaN
# 13398                  NaN           NaN                NaN
# 15587                  NaN           NaN                NaN
#
#        YouTubeTheNewBoston  monthly_spend
# 1728                   NaN    5000.000000
# 1755                   NaN    3333.333333
# 7989                   NaN    5000.000000
# 8126                   1.0    5000.000000
# 13398                  NaN   10000.000000
# 15587                  NaN    4166.666667
#
# [6 rows x 137 columns]

# %%
fcc_updated[bol2].index
# Out:
# Int64Index([1728, 1755, 7989, 8126, 13398, 15587], dtype='int64')

# %%
fcc_updated.columns
# Out:
# Index(['Age', 'AttendedBootcamp', 'BootcampFinish', 'BootcampLoanYesNo',
#        'BootcampName', 'BootcampRecommend', 'ChildrenNumber', 'CityPopulation',
#        'CodeEventConferences', 'CodeEventDjangoGirls', 'CodeEventFCC',
#        'CodeEventGameJam', 'CodeEventGirlDev', 'CodeEventHackathons',
#        'CodeEventMeetup', 'CodeEventNodeSchool', 'CodeEventNone',
#        'CodeEventOther', 'CodeEventRailsBridge', 'CodeEventRailsGirls',
#        'CodeEventStartUpWknd', 'CodeEventWkdBootcamps', 'CodeEventWomenCode',
#        'CodeEventWorkshops', 'CommuteTime', 'CountryCitizen', 'CountryLive',
#        'EmploymentField', 'EmploymentFieldOther', 'EmploymentStatus',
#        'EmploymentStatusOther', 'ExpectedEarning', 'FinanciallySupporting',
#        'FirstDevJob', 'Gender', 'GenderOther', 'HasChildren', 'HasDebt',
#        'HasFinancialDependents', 'HasHighSpdInternet', 'HasHomeMortgage',
#        'HasServedInMilitary', 'HasStudentDebt', 'HomeMortgageOwe',
#        'HoursLearning', 'ID.x', 'ID.y', 'Income', 'IsEthnicMinority',
#        'IsReceiveDisabilitiesBenefits', 'IsSoftwareDev', 'IsUnderEmployed',
#        'JobApplyWhen', 'JobInterestBackEnd', 'JobInterestDataEngr',
#        'JobInterestDataSci', 'JobInterestDevOps', 'JobInterestFrontEnd',
#        'JobInterestFullStack', 'JobInterestGameDev', 'JobInterestInfoSec',
#        'JobInterestMobile', 'JobInterestOther', 'JobInterestProjMngr',
#        'JobInterestQAEngr', 'JobInterestUX', 'JobPref', 'JobRelocateYesNo',
#        'JobRoleInterest', 'JobWherePref', 'LanguageAtHome', 'MaritalStatus',
#        'MoneyForLearning', 'MonthsProgramming', 'NetworkID', 'Part1EndTime',
#        'Part1StartTime', 'Part2EndTime', 'Part2StartTime', 'PodcastChangeLog',
#        'PodcastCodeNewbie', 'PodcastCodePen', 'PodcastDevTea', 'PodcastDotNET',
#        'PodcastGiantRobots', 'PodcastJSAir', 'PodcastJSJabber', 'PodcastNone',
#        'PodcastOther', 'PodcastProgThrowdown', 'PodcastRubyRogues',
#        'PodcastSEDaily', 'PodcastSERadio', 'PodcastShopTalk',
#        'PodcastTalkPython', 'PodcastTheWebAhead', 'ResourceCodecademy',
#        'ResourceCodeWars', 'ResourceCoursera', 'ResourceCSS', 'ResourceEdX',
#        'ResourceEgghead', 'ResourceFCC', 'ResourceHackerRank', 'ResourceKA',
#        'ResourceLynda', 'ResourceMDN', 'ResourceOdinProj', 'ResourceOther',
#        'ResourcePluralSight', 'ResourceSkillcrush', 'ResourceSO',
#        'ResourceTreehouse', 'ResourceUdacity', 'ResourceUdemy', 'ResourceW3S',
#        'SchoolDegree', 'SchoolMajor', 'StudentDebtOwe', 'YouTubeCodeCourse',
#        'YouTubeCodingTrain', 'YouTubeCodingTut360', 'YouTubeComputerphile',
#        'YouTubeDerekBanas', 'YouTubeDevTips', 'YouTubeEngineeredTruth',
#        'YouTubeFCC', 'YouTubeFunFunFunction', 'YouTubeGoogleDev',
#        'YouTubeLearnCode', 'YouTubeLevelUpTuts', 'YouTubeMIT',
#        'YouTubeMozillaHacks', 'YouTubeOther', 'YouTubeSimplilearn',
#        'YouTubeTheNewBoston', 'monthly_spend'],
#       dtype='object')

# %%
fcc_updated.drop(fcc_updated[bol2].index, inplace = True)

# %%
bol3 = (fcc_updated["CountryLive"] =="United States of America") & (fcc_updated["monthly_spend"] >= 6000)
fcc_updated[bol3]
# Out:
#         Age  AttendedBootcamp  BootcampFinish  BootcampLoanYesNo  \
# 718    26.0               1.0             0.0                0.0
# 1222   32.0               1.0             0.0                0.0
# 3184   34.0               1.0             1.0                0.0
# 3930   31.0               0.0             NaN                NaN
# 6805   46.0               1.0             1.0                1.0
# 7198   32.0               0.0             NaN                NaN
# 7505   26.0               1.0             0.0                1.0
# 9778   33.0               1.0             0.0                1.0
# 16650  29.0               0.0             NaN                NaN
# 16997  27.0               0.0             NaN                NaN
# 17231  50.0               0.0             NaN                NaN
#
#                                  BootcampName  BootcampRecommend  \
# 718    The Coding Boot Camp at UCLA Extension                1.0
# 1222                            The Iron Yard                1.0
# 3184                           We Can Code IT                1.0
# 3930                                      NaN                NaN
# 6805                                 Sabio.la                0.0
# 7198                                      NaN                NaN
# 7505                                   Codeup                0.0
# 9778                             Grand Circus                1.0
# 16650                                     NaN                NaN
# 16997                                     NaN                NaN
# 17231                                     NaN                NaN
#
#        ChildrenNumber                 CityPopulation  CodeEventConferences  \
# 718               NaN            more than 1 million                   1.0
# 1222              NaN  between 100,000 and 1 million                   NaN
# 3184              NaN            more than 1 million                   NaN
# 3930              NaN  between 100,000 and 1 million                   NaN
# 6805              NaN  between 100,000 and 1 million                   NaN
# 7198              NaN            more than 1 million                   1.0
# 7505              NaN            more than 1 million                   NaN
# 9778              NaN  between 100,000 and 1 million                   NaN
# 16650             2.0            more than 1 million                   NaN
# 16997             1.0            more than 1 million                   NaN
# 17231             2.0              less than 100,000                   NaN
#
#        CodeEventDjangoGirls  ...  YouTubeFunFunFunction  YouTubeGoogleDev  \
# 718                     NaN  ...                    NaN               NaN
# 1222                    NaN  ...                    NaN               NaN
# 3184                    NaN  ...                    NaN               NaN
# 3930                    NaN  ...                    1.0               1.0
# 6805                    NaN  ...                    NaN               NaN
# 7198                    NaN  ...                    NaN               1.0
# 7505                    NaN  ...                    NaN               NaN
# 9778                    NaN  ...                    NaN               NaN
# 16650                   NaN  ...                    NaN               NaN
# 16997                   NaN  ...                    NaN               NaN
# 17231                   NaN  ...                    NaN               NaN
#
#        YouTubeLearnCode  YouTubeLevelUpTuts  YouTubeMIT  YouTubeMozillaHacks  \
# 718                 NaN                 NaN         NaN                  NaN
# 1222                1.0                 NaN         NaN                  NaN
# 3184                NaN                 NaN         NaN                  NaN
# 3930                1.0                 1.0         1.0                  NaN
# 6805                NaN                 NaN         NaN                  NaN
# 7198                1.0                 1.0         NaN                  NaN
# 7505                NaN                 NaN         1.0                  NaN
# 9778                NaN                 NaN         NaN                  NaN
# 16650               NaN                 NaN         NaN                  NaN
# 16997               NaN                 NaN         NaN                  NaN
# 17231               NaN                 NaN         NaN                  NaN
#
#                      YouTubeOther YouTubeSimplilearn  YouTubeTheNewBoston  \
# 718                           NaN                NaN                  NaN
# 1222                          NaN                NaN                  NaN
# 3184                          NaN                NaN                  NaN
# 3930   various conf presentations                NaN                  NaN
# 6805                          NaN                NaN                  NaN
# 7198                          NaN                NaN                  NaN
# 7505                          NaN                NaN                  NaN
# 9778                          NaN                NaN                  NaN
# 16650                         NaN                NaN                  1.0
# 16997                         NaN                NaN                  NaN
# 17231                         NaN                NaN                  NaN
#
#        monthly_spend
# 718      8000.000000
# 1222     6500.000000
# 3184     9000.000000
# 3930    10833.333333
# 6805    15000.000000
# 7198    14000.000000
# 7505     6666.666667
# 9778     8000.000000
# 16650   16666.666667
# 16997   12500.000000
# 17231   15000.000000
#
# [11 rows x 137 columns]

# %%
bol4 = (fcc_updated["CountryLive"] =="United States of America") & (fcc_updated["monthly_spend"] >= 6000) & (fcc_updated["AttendedBootcamp"] == 0.0)
fcc_updated[bol4]
# Out:
#         Age  AttendedBootcamp  BootcampFinish  BootcampLoanYesNo BootcampName  \
# 3930   31.0               0.0             NaN                NaN          NaN
# 7198   32.0               0.0             NaN                NaN          NaN
# 16650  29.0               0.0             NaN                NaN          NaN
# 16997  27.0               0.0             NaN                NaN          NaN
# 17231  50.0               0.0             NaN                NaN          NaN
#
#        BootcampRecommend  ChildrenNumber                 CityPopulation  \
# 3930                 NaN             NaN  between 100,000 and 1 million
# 7198                 NaN             NaN            more than 1 million
# 16650                NaN             2.0            more than 1 million
# 16997                NaN             1.0            more than 1 million
# 17231                NaN             2.0              less than 100,000
#
#        CodeEventConferences  CodeEventDjangoGirls  ...  YouTubeFunFunFunction  \
# 3930                    NaN                   NaN  ...                    1.0
# 7198                    1.0                   NaN  ...                    NaN
# 16650                   NaN                   NaN  ...                    NaN
# 16997                   NaN                   NaN  ...                    NaN
# 17231                   NaN                   NaN  ...                    NaN
#
#        YouTubeGoogleDev  YouTubeLearnCode  YouTubeLevelUpTuts  YouTubeMIT  \
# 3930                1.0               1.0                 1.0         1.0
# 7198                1.0               1.0                 1.0         NaN
# 16650               NaN               NaN                 NaN         NaN
# 16997               NaN               NaN                 NaN         NaN
# 17231               NaN               NaN                 NaN         NaN
#
#        YouTubeMozillaHacks                YouTubeOther YouTubeSimplilearn  \
# 3930                   NaN  various conf presentations                NaN
# 7198                   NaN                         NaN                NaN
# 16650                  NaN                         NaN                NaN
# 16997                  NaN                         NaN                NaN
# 17231                  NaN                         NaN                NaN
#
#        YouTubeTheNewBoston  monthly_spend
# 3930                   NaN   10833.333333
# 7198                   NaN   14000.000000
# 16650                  1.0   16666.666667
# 16997                  NaN   12500.000000
# 17231                  NaN   15000.000000
#
# [5 rows x 137 columns]

# %%
fcc_updated.drop(fcc_updated[bol4].index, inplace = True)

# %%
pd.options.display.max_columns = None

# %%
bol3 = (fcc_updated["CountryLive"] =="United States of America") & (fcc_updated["monthly_spend"] >= 6000)
fcc_updated[bol3][["MonthsProgramming", "monthly_spend"]]
# Out:
#       MonthsProgramming  monthly_spend
# 718                 1.0    8000.000000
# 1222                2.0    6500.000000
# 3184                1.0    9000.000000
# 6805                1.0   15000.000000
# 7505                3.0    6666.666667
# 9778                1.0    8000.000000

# %%
bol5 = (fcc_updated["CountryLive"] =="United States of America") & (fcc_updated["monthly_spend"] >= 6000) & (fcc_updated["MonthsProgramming"] <= 3)
fcc_updated[bol5]
# Out:
#        Age  AttendedBootcamp  BootcampFinish  BootcampLoanYesNo  \
# 718   26.0               1.0             0.0                0.0
# 1222  32.0               1.0             0.0                0.0
# 3184  34.0               1.0             1.0                0.0
# 6805  46.0               1.0             1.0                1.0
# 7505  26.0               1.0             0.0                1.0
# 9778  33.0               1.0             0.0                1.0
#
#                                 BootcampName  BootcampRecommend  \
# 718   The Coding Boot Camp at UCLA Extension                1.0
# 1222                           The Iron Yard                1.0
# 3184                          We Can Code IT                1.0
# 6805                                Sabio.la                0.0
# 7505                                  Codeup                0.0
# 9778                            Grand Circus                1.0
#
#       ChildrenNumber                 CityPopulation  CodeEventConferences  \
# 718              NaN            more than 1 million                   1.0
# 1222             NaN  between 100,000 and 1 million                   NaN
# 3184             NaN            more than 1 million                   NaN
# 6805             NaN  between 100,000 and 1 million                   NaN
# 7505             NaN            more than 1 million                   NaN
# 9778             NaN  between 100,000 and 1 million                   NaN
#
#       CodeEventDjangoGirls  CodeEventFCC  CodeEventGameJam  CodeEventGirlDev  \
# 718                    NaN           NaN               NaN               NaN
# 1222                   NaN           NaN               NaN               NaN
# 3184                   NaN           NaN               NaN               NaN
# 6805                   NaN           NaN               NaN               NaN
# 7505                   NaN           NaN               NaN               NaN
# 9778                   NaN           NaN               NaN               NaN
#
#       CodeEventHackathons  CodeEventMeetup  CodeEventNodeSchool  \
# 718                   NaN              NaN                  NaN
# 1222                  NaN              1.0                  NaN
# 3184                  NaN              1.0                  NaN
# 6805                  NaN              NaN                  NaN
# 7505                  NaN              NaN                  NaN
# 9778                  NaN              1.0                  NaN
#
#       CodeEventNone CodeEventOther  CodeEventRailsBridge  CodeEventRailsGirls  \
# 718             NaN            NaN                   NaN                  NaN
# 1222            NaN            NaN                   NaN                  NaN
# 3184            NaN            NaN                   NaN                  NaN
# 6805            NaN            NaN                   NaN                  NaN
# 7505            NaN            NaN                   NaN                  NaN
# 9778            NaN            NaN                   NaN                  NaN
#
#       CodeEventStartUpWknd  CodeEventWkdBootcamps  CodeEventWomenCode  \
# 718                    NaN                    NaN                 NaN
# 1222                   NaN                    NaN                 NaN
# 3184                   NaN                    NaN                 NaN
# 6805                   NaN                    NaN                 NaN
# 7505                   1.0                    NaN                 NaN
# 9778                   NaN                    NaN                 NaN
#
#       CodeEventWorkshops           CommuteTime            CountryCitizen  \
# 718                  NaN      15 to 29 minutes  United States of America
# 1222                 NaN                   NaN  United States of America
# 3184                 NaN  Less than 15 minutes                       NaN
# 6805                 NaN                   NaN  United States of America
# 7505                 NaN                   NaN  United States of America
# 9778                 NaN      15 to 29 minutes  United States of America
#
#                    CountryLive                       EmploymentField  \
# 718   United States of America  architecture or physical engineering
# 1222  United States of America                                   NaN
# 3184  United States of America           software development and IT
# 6805  United States of America                                   NaN
# 7505  United States of America                                   NaN
# 9778  United States of America                             education
#
#      EmploymentFieldOther                      EmploymentStatus  \
# 718                   NaN                    Employed for wages
# 1222                  NaN  Not working and not looking for work
# 3184                  NaN                    Employed for wages
# 6805                  NaN      Not working but looking for work
# 7505                  NaN      Not working but looking for work
# 9778                  NaN                    Employed for wages
#
#      EmploymentStatusOther  ExpectedEarning  FinanciallySupporting  \
# 718                    NaN          50000.0                    NaN
# 1222                   NaN          50000.0                    NaN
# 3184                   NaN          60000.0                    NaN
# 6805                   NaN          70000.0                    NaN
# 7505                   NaN          65000.0                    NaN
# 9778                   NaN          55000.0                    NaN
#
#       FirstDevJob  Gender GenderOther  HasChildren  HasDebt  \
# 718           NaN    male         NaN          NaN      0.0
# 1222          NaN  female         NaN          NaN      1.0
# 3184          NaN    male         NaN          NaN      0.0
# 6805          NaN    male         NaN          NaN      1.0
# 7505          NaN    male         NaN          NaN      1.0
# 9778          NaN    male         NaN          NaN      1.0
#
#       HasFinancialDependents  HasHighSpdInternet  HasHomeMortgage  \
# 718                      0.0                 0.0              NaN
# 1222                     0.0                 1.0              0.0
# 3184                     0.0                 1.0              NaN
# 6805                     0.0                 1.0              0.0
# 7505                     0.0                 1.0              0.0
# 9778                     0.0                 1.0              0.0
#
#       HasServedInMilitary  HasStudentDebt  HomeMortgageOwe  HoursLearning  \
# 718                   0.0             NaN              NaN           35.0
# 1222                  0.0             0.0              NaN           50.0
# 3184                  0.0             NaN              NaN           10.0
# 6805                  0.0             1.0              NaN           45.0
# 7505                  0.0             1.0              NaN           40.0
# 9778                  0.0             1.0              NaN           40.0
#
#                                   ID.x                              ID.y  \
# 718   796ae14c2acdee36eebc250a252abdaf  d9e44d73057fa5d322a071adc744bf07
# 1222  bfabebb4293ac002d26a1397d00c7443  590f0be70e80f1daf5a23eb7f4a72a3d
# 3184  5d4889491d9d25a255e57fd1c0022458  585e8f8b9a838ef1abbe8c6f1891c048
# 6805  69096aacf4245694303cf8f7ce68a63f  4c56f82a348836e76dd90d18a3d5ed88
# 7505  657fb50800bcc99a07caf52387f67fbb  ad1df4669883d8f628f0b5598a4c5c45
# 9778  7a62790f6ded15e26d5f429b8a4d1095  98eeee1aa81ba70b2ab288bf4b63d703
#
#        Income  IsEthnicMinority  IsReceiveDisabilitiesBenefits  IsSoftwareDev  \
# 718   44500.0               0.0                            0.0            0.0
# 1222      NaN               0.0                            0.0            0.0
# 3184  40000.0               0.0                            0.0            0.0
# 6805      NaN               1.0                            0.0            0.0
# 7505      NaN               0.0                            0.0            0.0
# 9778  20000.0               0.0                            0.0            0.0
#
#       IsUnderEmployed              JobApplyWhen  JobInterestBackEnd  \
# 718               1.0  Within the next 6 months                 1.0
# 1222              NaN  Within the next 6 months                 NaN
# 3184              0.0         I haven't decided                 NaN
# 6805              NaN  Within the next 6 months                 NaN
# 7505              NaN  Within the next 6 months                 1.0
# 9778              1.0  Within the next 6 months                 1.0
#
#       JobInterestDataEngr  JobInterestDataSci  JobInterestDevOps  \
# 718                   NaN                 NaN                NaN
# 1222                  NaN                 NaN                NaN
# 3184                  1.0                 1.0                1.0
# 6805                  1.0                 1.0                NaN
# 7505                  NaN                 NaN                NaN
# 9778                  1.0                 1.0                NaN
#
#       JobInterestFrontEnd  JobInterestFullStack  JobInterestGameDev  \
# 718                   1.0                   1.0                 NaN
# 1222                  1.0                   NaN                 NaN
# 3184                  NaN                   NaN                 NaN
# 6805                  NaN                   1.0                 1.0
# 7505                  1.0                   1.0                 NaN
# 9778                  NaN                   1.0                 NaN
#
#       JobInterestInfoSec  JobInterestMobile JobInterestOther  \
# 718                  NaN                1.0              NaN
# 1222                 NaN                1.0              NaN
# 3184                 1.0                NaN              NaN
# 6805                 NaN                NaN              NaN
# 7505                 1.0                1.0              NaN
# 9778                 NaN                1.0              NaN
#
#       JobInterestProjMngr  JobInterestQAEngr  JobInterestUX  \
# 718                   NaN                NaN            1.0
# 1222                  NaN                NaN            1.0
# 3184                  NaN                1.0            1.0
# 6805                  1.0                NaN            NaN
# 7505                  NaN                NaN            NaN
# 9778                  NaN                1.0            NaN
#
#                                    JobPref  JobRelocateYesNo  \
# 718                     work for a startup               1.0
# 1222                  work for a nonprofit               1.0
# 3184       work for a medium-sized company               0.0
# 6805  work for a multinational corporation               1.0
# 7505                 work for a government               1.0
# 9778       work for a medium-sized company               NaN
#
#                                         JobRoleInterest  \
# 718     User Experience Designer, Full-Stack Web Dev...
# 1222    Front-End Web Developer,   Mobile Developer,...
# 3184    Quality Assurance Engineer,   DevOps / SysAd...
# 6805  Full-Stack Web Developer, Game Developer,   Pr...
# 7505    Mobile Developer, Full-Stack Web Developer, ...
# 9778  Full-Stack Web Developer, Data Engineer,   Qua...
#
#                             JobWherePref LanguageAtHome  \
# 718   in an office with other developers        English
# 1222  in an office with other developers        English
# 3184  in an office with other developers        English
# 6805                       no preference        English
# 7505  in an office with other developers        English
# 9778                           from home        English
#
#                         MaritalStatus  MoneyForLearning  MonthsProgramming  \
# 718             single, never married            8000.0                1.0
# 1222            single, never married           13000.0                2.0
# 3184            single, never married            9000.0                1.0
# 6805  married or domestic partnership           15000.0                1.0
# 7505            single, never married           20000.0                3.0
# 9778            single, never married            8000.0                1.0
#
#        NetworkID         Part1EndTime       Part1StartTime  \
# 718   50dab3f716  2017-03-09 21:26:35  2017-03-09 21:21:58
# 1222  e512c4bdd0  2017-03-10 02:14:11  2017-03-10 02:10:07
# 3184  e7bebaabd4  2017-03-11 23:34:16  2017-03-11 23:31:17
# 6805  53d13b58e9  2017-03-21 20:13:08  2017-03-21 20:10:25
# 7505  96e254de36  2017-03-24 03:26:09  2017-03-24 03:23:02
# 9778  ea80a3b15e  2017-04-05 19:48:12  2017-04-05 19:40:19
#
#              Part2EndTime       Part2StartTime  PodcastChangeLog  \
# 718   2017-03-09 21:29:10  2017-03-09 21:26:39               NaN
# 1222  2017-03-10 02:15:32  2017-03-10 02:14:16               NaN
# 3184  2017-03-11 23:36:02  2017-03-11 23:34:21               NaN
# 6805  2017-03-21 20:14:36  2017-03-21 20:13:11               NaN
# 7505  2017-03-24 03:27:47  2017-03-24 03:26:14               NaN
# 9778  2017-04-05 19:49:44  2017-04-05 19:49:03               NaN
#
#       PodcastCodeNewbie  PodcastCodePen  PodcastDevTea  PodcastDotNET  \
# 718                 1.0             1.0            NaN            NaN
# 1222                NaN             NaN            NaN            NaN
# 3184                1.0             NaN            NaN            NaN
# 6805                NaN             NaN            NaN            NaN
# 7505                NaN             NaN            1.0            NaN
# 9778                NaN             NaN            NaN            NaN
#
#       PodcastGiantRobots  PodcastJSAir  PodcastJSJabber  PodcastNone  \
# 718                  NaN           NaN              NaN          NaN
# 1222                 NaN           NaN              1.0          NaN
# 3184                 NaN           NaN              NaN          NaN
# 6805                 NaN           NaN              NaN          NaN
# 7505                 NaN           NaN              NaN          NaN
# 9778                 NaN           NaN              NaN          NaN
#
#      PodcastOther  PodcastProgThrowdown  PodcastRubyRogues  PodcastSEDaily  \
# 718           NaN                   NaN                NaN             1.0
# 1222          NaN                   NaN                NaN             NaN
# 3184          NaN                   NaN                NaN             1.0
# 6805          NaN                   NaN                NaN             NaN
# 7505          NaN                   NaN                NaN             NaN
# 9778          NaN                   NaN                NaN             NaN
#
#       PodcastSERadio  PodcastShopTalk  PodcastTalkPython  PodcastTheWebAhead  \
# 718              NaN              NaN                NaN                 NaN
# 1222             NaN              NaN                NaN                 NaN
# 3184             NaN              NaN                NaN                 NaN
# 6805             NaN              NaN                NaN                 NaN
# 7505             NaN              NaN                NaN                 NaN
# 9778             NaN              NaN                NaN                 NaN
#
#       ResourceCodecademy  ResourceCodeWars  ResourceCoursera  ResourceCSS  \
# 718                  NaN               1.0               NaN          NaN
# 1222                 1.0               NaN               NaN          1.0
# 3184                 NaN               1.0               NaN          1.0
# 6805                 1.0               NaN               NaN          NaN
# 7505                 1.0               NaN               NaN          NaN
# 9778                 NaN               NaN               NaN          NaN
#
#       ResourceEdX  ResourceEgghead  ResourceFCC  ResourceHackerRank  \
# 718           NaN              NaN          1.0                 NaN
# 1222          NaN              1.0          1.0                 NaN
# 3184          NaN              NaN          NaN                 NaN
# 6805          NaN              NaN          1.0                 NaN
# 7505          NaN              NaN          1.0                 NaN
# 9778          NaN              NaN          1.0                 NaN
#
#       ResourceKA  ResourceLynda  ResourceMDN  ResourceOdinProj ResourceOther  \
# 718          NaN            NaN          NaN               NaN           NaN
# 1222         NaN            NaN          1.0               NaN           NaN
# 3184         NaN            NaN          NaN               NaN           NaN
# 6805         NaN            NaN          NaN               NaN           NaN
# 7505         NaN            1.0          NaN               NaN           NaN
# 9778         NaN            NaN          NaN               NaN           NaN
#
#       ResourcePluralSight  ResourceSkillcrush  ResourceSO  ResourceTreehouse  \
# 718                   NaN                 NaN         NaN                NaN
# 1222                  1.0                 1.0         1.0                1.0
# 3184                  NaN                 NaN         1.0                NaN
# 6805                  NaN                 NaN         1.0                1.0
# 7505                  1.0                 NaN         1.0                NaN
# 9778                  NaN                 NaN         1.0                1.0
#
#       ResourceUdacity  ResourceUdemy  ResourceW3S  \
# 718               NaN            NaN          NaN
# 1222              1.0            1.0          NaN
# 3184              1.0            1.0          1.0
# 6805              1.0            1.0          1.0
# 7505              NaN            1.0          1.0
# 9778              1.0            NaN          NaN
#
#                             SchoolDegree  \
# 718                    bachelor's degree
# 1222                   bachelor's degree
# 3184      some college credit, no degree
# 6805                   bachelor's degree
# 7505                   bachelor's degree
# 9778  master's degree (non-professional)
#
#                                  SchoolMajor  StudentDebtOwe  \
# 718                             Architecture             NaN
# 1222                            Anthropology             NaN
# 3184                                     NaN             NaN
# 6805  Business Administration and Management         45000.0
# 7505                               Economics         20000.0
# 9778                    Chemical Engineering         45000.0
#
#       YouTubeCodeCourse  YouTubeCodingTrain  YouTubeCodingTut360  \
# 718                 NaN                 NaN                  NaN
# 1222                NaN                 1.0                  NaN
# 3184                NaN                 NaN                  NaN
# 6805                NaN                 NaN                  NaN
# 7505                NaN                 NaN                  NaN
# 9778                NaN                 NaN                  NaN
#
#       YouTubeComputerphile  YouTubeDerekBanas  YouTubeDevTips  \
# 718                    NaN                NaN             NaN
# 1222                   NaN                NaN             1.0
# 3184                   NaN                NaN             NaN
# 6805                   NaN                NaN             NaN
# 7505                   NaN                NaN             NaN
# 9778                   NaN                NaN             NaN
#
#       YouTubeEngineeredTruth  YouTubeFCC  YouTubeFunFunFunction  \
# 718                      NaN         1.0                    NaN
# 1222                     NaN         1.0                    NaN
# 3184                     NaN         NaN                    NaN
# 6805                     NaN         1.0                    NaN
# 7505                     NaN         NaN                    NaN
# 9778                     NaN         NaN                    NaN
#
#       YouTubeGoogleDev  YouTubeLearnCode  YouTubeLevelUpTuts  YouTubeMIT  \
# 718                NaN               NaN                 NaN         NaN
# 1222               NaN               1.0                 NaN         NaN
# 3184               NaN               NaN                 NaN         NaN
# 6805               NaN               NaN                 NaN         NaN
# 7505               NaN               NaN                 NaN         1.0
# 9778               NaN               NaN                 NaN         NaN
#
#       YouTubeMozillaHacks YouTubeOther  YouTubeSimplilearn  \
# 718                   NaN          NaN                 NaN
# 1222                  NaN          NaN                 NaN
# 3184                  NaN          NaN                 NaN
# 6805                  NaN          NaN                 NaN
# 7505                  NaN          NaN                 NaN
# 9778                  NaN          NaN                 NaN
#
#       YouTubeTheNewBoston  monthly_spend
# 718                   NaN    8000.000000
# 1222                  NaN    6500.000000
# 3184                  NaN    9000.000000
# 6805                  NaN   15000.000000
# 7505                  NaN    6666.666667
# 9778                  NaN    8000.000000

# %%
fcc_updated.drop(fcc_updated[bol5].index, inplace = True)

# %%
bol6 = (fcc_updated["CountryLive"] =="Canada") & (fcc_updated["monthly_spend"] > 4500)

# %%
fcc_updated[bol6][["MonthsProgramming", "monthly_spend"]]
# Out:
#        MonthsProgramming  monthly_spend
# 13659                2.0         5000.0

# %%
fcc_updated.drop(fcc_updated[bol6].index, inplace = True)

# %%
fcc_updated.groupby("CountryLive")["monthly_spend"].mean().sort_values(ascending = False)
# Out:
# CountryLive
# United States of America    142.654608
# Canada                       93.065400
# India                        65.758763
# United Kingdom               45.534443
# Name: monthly_spend, dtype: float64

# %%
sns.boxplot(x = "CountryLive", y ="monthly_spend", data =  fcc_updated, whis = 1.5)

# %%
iqr = upperperc-lowerperc

iqr*1.5

# %%
upper_out =  upperperc+iqr*2

# %%
fcc_updated["CountryLive"].value_counts(normalize = True)
# Out:
# United States of America    0.749679
# India                       0.117330
# United Kingdom              0.071630
# Canada                      0.061361
# Name: CountryLive, dtype: float64

# %% [markdown]
# 1. USA alone
# 2. USA (80%), India(10%),canda(10%)
# 3. USA, Canada
# 4. USA, India

# %%
sns.boxplot(x = "CountryLive", y ="monthly_spend", data =  fcc_updated)
plt.title("Comparision", y = 1.05)
plt.xlabel("Countries")
plt.ylabel("spending")
plt.xticks(rotation = 45)
plt.show()
